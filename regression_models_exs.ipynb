# %% [markdown]
# # Regression model exercises

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures

import wrangle

# %%
df = wrangle.wrangle_zillow_data()
# Out:
# Returning saved csv file.

# %% [markdown]
# Scale the data

# %%
df, scalers = wrangle.zillow_scale(df, columns=['calculatedfinishedsquarefeet'], return_scalers=True)
df
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 4                 4          2.0                          3633       2005
# 6                 3          4.0                          1620       2011
# 7                 3          2.0                          2077       1926
# 18                3          1.0                          1244       1950
# 19                3          2.0                          1300       1950
# ...             ...          ...                           ...        ...
# 2152856           4          4.0                          4375       2015
# 2152858           4          3.0                          2262       2015
# 2152859           4          4.5                          3127       2014
# 2152861           3          2.5                          1974       2015
# 2152862           4          4.0                          2110       2014
#
#          taxvaluedollarcnt       county  calculatedfinishedsquarefeet_scaled
# 4                   296425  Los Angeles                             2.236203
# 6                   847770  Los Angeles                             0.014349
# 7                   646760  Los Angeles                             0.518764
# 18                  169471  Los Angeles                            -0.400662
# 19                  233266  Los Angeles                            -0.338852
# ...                    ...          ...                                  ...
# 2152856             422400  Los Angeles                             3.055188
# 2152858             960756       Orange                             0.722958
# 2152859             536061       Orange                             1.677704
# 2152861             424353       Orange                             0.405077
# 2152862             554009  Los Angeles                             0.555188
#
# [2087536 rows x 7 columns]

# %%
train, validate, test = wrangle.split_zillow_data(df)

# %%
train
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 1174234           4          2.0                          2015       1968
# 892222            3          2.0                          1423       1940
# 2056706           4          2.0                          2508       1987
# 666486            3          2.5                          1789       1974
# 2068010           4          4.0                          2829       1961
# ...             ...          ...                           ...        ...
# 421920            5          3.0                          2834       1956
# 1204808           2          1.5                          1366       1977
# 2002848           3          2.0                          1699       1971
# 1731210           3          2.0                          1362       1968
# 418158            3          2.5                          2421       1989
#
#          taxvaluedollarcnt       county  calculatedfinishedsquarefeet_scaled
# 1174234             273762      Ventura                             0.450331
# 892222              276396       Orange                            -0.203091
# 2056706             456054      Ventura                             0.994481
# 666486              357041       Orange                             0.200883
# 2068010             690548  Los Angeles                             1.348786
# ...                    ...          ...                                  ...
# 421920              481909  Los Angeles                             1.354305
# 1204808             436161       Orange                            -0.266004
# 2002848             496344      Ventura                             0.101545
# 1731210              66093       Orange                            -0.270419
# 418158              832000       Orange                             0.898455
#
# [1169019 rows x 7 columns]

# %% [markdown]
# Make `X_train`, `y_train`, `X_validate` and `y_validate`

# %%
X_train = train.drop(columns = ['taxvaluedollarcnt', 'county', 'calculatedfinishedsquarefeet'])
y_train = pd.DataFrame(train[['taxvaluedollarcnt']])

X_validate = validate.drop(columns = ['taxvaluedollarcnt', 'county', 'calculatedfinishedsquarefeet'])
y_validate = pd.DataFrame(validate[['taxvaluedollarcnt']])

# %%
y_train
# Out:
#          taxvaluedollarcnt
# 1174234             273762
# 892222              276396
# 2056706             456054
# 666486              357041
# 2068010             690548
# ...                    ...
# 421920              481909
# 1204808             436161
# 2002848             496344
# 1731210              66093
# 418158              832000
#
# [1169019 rows x 1 columns]

# %%
X_train
# Out:
#          bedroomcnt  bathroomcnt  yearbuilt  \
# 1174234           4          2.0       1968
# 892222            3          2.0       1940
# 2056706           4          2.0       1987
# 666486            3          2.5       1974
# 2068010           4          4.0       1961
# ...             ...          ...        ...
# 421920            5          3.0       1956
# 1204808           2          1.5       1977
# 2002848           3          2.0       1971
# 1731210           3          2.0       1968
# 418158            3          2.5       1989
#
#          calculatedfinishedsquarefeet_scaled
# 1174234                             0.450331
# 892222                             -0.203091
# 2056706                             0.994481
# 666486                              0.200883
# 2068010                             1.348786
# ...                                      ...
# 421920                              1.354305
# 1204808                            -0.266004
# 2002848                             0.101545
# 1731210                            -0.270419
# 418158                              0.898455
#
# [1169019 rows x 4 columns]

# %%
y_train['taxvaluedollarcnt'].mean()
# Out:
# 398120.95571158384

# %% [markdown]
# ## Baseline model
#
# use the mean and the median to see which is better

# %%
#mean baseline model
y_train['baseline_mean_pred'] = y_train['taxvaluedollarcnt'].mean()
y_validate['baseline_mean_pred'] = y_validate['taxvaluedollarcnt'].mean()

#median baseline model
y_train['baseline_median_pred'] = y_train['taxvaluedollarcnt'].median()
y_validate['baseline_median_pred'] = y_validate['taxvaluedollarcnt'].median()

# %%
#determine RSMSE
results = []

baseline_mean = {
    'model':'baseline_mean',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['baseline_mean_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['baseline_mean_pred'])**(0.5)

}
baseline_median = {
    'model':'baseline_median',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['baseline_median_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['baseline_median_pred'])**(0.5)

}
results.append(baseline_mean)
results.append(baseline_median)

# %%
pd.DataFrame(results)
# Out:
#              model     RMSE_train  RMSE_validate
# 0    baseline_mean  312099.231468  311678.065140
# 1  baseline_median  321236.237971  320680.947753

# %% [markdown]
# ## Linear Regression model

# %%
lm = LinearRegression(normalize = True)

lm.fit(X_train, y_train['taxvaluedollarcnt'])

y_train['lm_train_pred'] = lm.predict(X_train)

y_validate['lm_validate_pred'] = lm.predict(X_validate)

y_train
# Out:
#          taxvaluedollarcnt  baseline_mean_pred  baseline_median_pred  \
# 1174234             273762       398120.955712              322050.0
# 892222              276396       398120.955712              322050.0
# 2056706             456054       398120.955712              322050.0
# 666486              357041       398120.955712              322050.0
# 2068010             690548       398120.955712              322050.0
# ...                    ...                 ...                   ...
# 421920              481909       398120.955712              322050.0
# 1204808             436161       398120.955712              322050.0
# 2002848             496344       398120.955712              322050.0
# 1731210              66093       398120.955712              322050.0
# 418158              832000       398120.955712              322050.0
#
#          lm_train_pred
# 1174234  393222.793630
# 892222   323918.088586
# 2056706  503264.979786
# 666486   428034.805547
# 2068010  695257.988865
# ...                ...
# 421920   581050.652406
# 1204808  334903.303898
# 2002848  380231.602378
# 1731210  302414.285242
# 418158   571534.917247
#
# [1169019 rows x 4 columns]

# %%
lm_rmse = {
    'model':'linear regression',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['lm_train_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['lm_validate_pred'])**(0.5)

}
results.append(lm_rmse)
pd.DataFrame(results)
# Out:
#                model     RMSE_train  RMSE_validate
# 0      baseline_mean  312099.231468  311678.065140
# 1    baseline_median  321236.237971  320680.947753
# 2  linear regression  249432.591414  249380.823468

# %% [markdown]
# ## LassoLars model

# %%
lars = LassoLars(alpha=1.0)

lars.fit(X_train, y_train['taxvaluedollarcnt'])

y_train['lars_train_pred'] = lars.predict(X_train)

y_validate['lars_validate_pred'] = lars.predict(X_validate)

y_train
# Out:
#          taxvaluedollarcnt  baseline_mean_pred  baseline_median_pred  \
# 1174234             273762       398120.955712              322050.0
# 892222              276396       398120.955712              322050.0
# 2056706             456054       398120.955712              322050.0
# 666486              357041       398120.955712              322050.0
# 2068010             690548       398120.955712              322050.0
# ...                    ...                 ...                   ...
# 421920              481909       398120.955712              322050.0
# 1204808             436161       398120.955712              322050.0
# 2002848             496344       398120.955712              322050.0
# 1731210              66093       398120.955712              322050.0
# 418158              832000       398120.955712              322050.0
#
#          lm_train_pred  lars_train_pred
# 1174234  393222.793630    396462.835722
# 892222   323918.088586    322322.770932
# 2056706  503264.979786    507245.462213
# 666486   428034.805547    427507.086379
# 2068010  695257.988865    689778.328269
# ...                ...              ...
# 421920   581050.652406    581484.699338
# 1204808  334903.303898    335305.136364
# 2002848  380231.602378    381124.915766
# 1731210  302414.285242    303818.777400
# 418158   571534.917247    571003.336046
#
# [1169019 rows x 5 columns]

# %%
lars_rmse = {
    'model':'LassoLars regression',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['lars_train_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['lars_validate_pred'])**(0.5)

}
results.append(lars_rmse)
pd.DataFrame(results)
# Out:
#                   model     RMSE_train  RMSE_validate
# 0         baseline_mean  312099.231468  311678.065140
# 1       baseline_median  321236.237971  320680.947753
# 2     linear regression  249432.591414  249380.823468
# 3  LassoLars regression  249453.620291  249390.926181

# %% [markdown]
# ## Polynomial Regression

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled
X_train_degree2 = pf.fit_transform(X_train)

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate)

# %%
# create the model object
lm2 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm2.fit(X_train_degree2, y_train['taxvaluedollarcnt'])

# predict train
y_train['poly_train_pred'] = lm2.predict(X_train_degree2)

# predict validate
y_validate['poly_validate_pred'] = lm2.predict(X_validate_degree2)

# %%
y_train
# Out:
#          taxvaluedollarcnt  baseline_mean_pred  baseline_median_pred  \
# 1174234             273762       398120.955712              322050.0
# 892222              276396       398120.955712              322050.0
# 2056706             456054       398120.955712              322050.0
# 666486              357041       398120.955712              322050.0
# 2068010             690548       398120.955712              322050.0
# ...                    ...                 ...                   ...
# 421920              481909       398120.955712              322050.0
# 1204808             436161       398120.955712              322050.0
# 2002848             496344       398120.955712              322050.0
# 1731210              66093       398120.955712              322050.0
# 418158              832000       398120.955712              322050.0
#
#          lm_train_pred  lars_train_pred  poly_train_pred
# 1174234  393222.793630    396462.835722    381352.305427
# 892222   323918.088586    322322.770932    322648.179255
# 2056706  503264.979786    507245.462213    496754.156838
# 666486   428034.805547    427507.086379    408772.507546
# 2068010  695257.988865    689778.328269    696678.845422
# ...                ...              ...              ...
# 421920   581050.652406    581484.699338    547956.930804
# 1204808  334903.303898    335305.136364    328771.226790
# 2002848  380231.602378    381124.915766    365508.922674
# 1731210  302414.285242    303818.777400    290501.476413
# 418158   571534.917247    571003.336046    569575.402621
#
# [1169019 rows x 6 columns]

# %%
poly_rmse = {
    'model':'Polynomial regression',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['poly_train_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['poly_validate_pred'])**(0.5)

}
results.append(poly_rmse)
pd.DataFrame(results)
# Out:
#                    model     RMSE_train  RMSE_validate
# 0          baseline_mean  312099.231468  311678.065140
# 1        baseline_median  321236.237971  320680.947753
# 2      linear regression  249432.591414  249380.823468
# 3   LassoLars regression  249453.620291  249390.926181
# 4  Polynomial regression  247593.831931  247453.300464

# %% [markdown]
# ## TweedieRegressor

# %%
glm = TweedieRegressor()

glm.fit(X_train, y_train['taxvaluedollarcnt'])

y_train['glm_train_pred'] = glm.predict(X_train)

y_validate['glm_validate_pred'] = glm.predict(X_validate)

y_train
# Out:
#          taxvaluedollarcnt  baseline_mean_pred  baseline_median_pred  \
# 1174234             273762       398120.955712              322050.0
# 892222              276396       398120.955712              322050.0
# 2056706             456054       398120.955712              322050.0
# 666486              357041       398120.955712              322050.0
# 2068010             690548       398120.955712              322050.0
# ...                    ...                 ...                   ...
# 421920              481909       398120.955712              322050.0
# 1204808             436161       398120.955712              322050.0
# 2002848             496344       398120.955712              322050.0
# 1731210              66093       398120.955712              322050.0
# 418158              832000       398120.955712              322050.0
#
#          lm_train_pred  lars_train_pred  poly_train_pred  glm_train_pred
# 1174234  393222.793630    396462.835722    381352.305427   422078.084825
# 892222   323918.088586    322322.770932    322648.179255   327519.456800
# 2056706  503264.979786    507245.462213    496754.156838   488452.118020
# 666486   428034.805547    427507.086379    408772.507546   432594.783641
# 2068010  695257.988865    689778.328269    696678.845422   557811.198738
# ...                ...              ...              ...             ...
# 421920   581050.652406    581484.699338    547956.930804   510878.911480
# 1204808  334903.303898    335305.136364    328771.226790   356574.859222
# 2002848  380231.602378    381124.915766    365508.922674   398698.559920
# 1731210  302414.285242    303818.777400    290501.476413   370013.838181
# 418158   571534.917247    571003.336046    569575.402621   502050.143561
#
# [1169019 rows x 7 columns]

# %%
glm_rmse = {
    'model':'TweedieRegressor regression',
    'RMSE_train': mean_squared_error(y_train['taxvaluedollarcnt'], y_train['glm_train_pred'])**(0.5),
    'RMSE_validate': mean_squared_error(y_validate['taxvaluedollarcnt'], y_validate['glm_validate_pred'])**(0.5)

}
results.append(glm_rmse)
pd.DataFrame(results)
# Out:
#                          model     RMSE_train  RMSE_validate
# 0                baseline_mean  312099.231468  311678.065140
# 1              baseline_median  321236.237971  320680.947753
# 2            linear regression  249432.591414  249380.823468
# 3         LassoLars regression  249453.620291  249390.926181
# 4        Polynomial regression  247593.831931  247453.300464
# 5  TweedieRegressor regression  267666.907672  267314.089061

# %%
results_df = pd.DataFrame(results)
results_df.sort_values(['RMSE_])
